# %% [markdown]
# FlowerFinder

# %% [markdown]
# Download Repository

# %%
# !git clone https://github.com/schlenkibus/yoltv5.git
# Out:
# Cloning into 'yoltv5'...
# remote: Enumerating objects: 256, done.
# remote: Counting objects: 100% (256/256), done.
# remote: Compressing objects: 100% (187/187), done.
# remote: Total 256 (delta 104), reused 205 (delta 58), pack-reused 0
# Receiving objects: 100% (256/256), 1.87 MiB | 16.07 MiB/s, done.
# Resolving deltas: 100% (104/104), done.

# %%
# %cd /content/yoltv5
# !git pull origin main
# Out:
# /content/yoltv5
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 9 (delta 8), reused 9 (delta 8), pack-reused 0
# Unpacking objects: 100% (9/9), done.
# From https://github.com/schlenkibus/yoltv5
#  * branch            main       -> FETCH_HEAD
#    28735cb..6246fc5  main       -> origin/main
# Updating 28735cb..6246fc5
# Fast-forward
#  test-inference-originals.sh     |  2 +-
#  test-inference-tif.sh           |  2 +-
#  test-inference-tifs.sh          |  2 +-
#  test-inference.sh               |  2 +-
#  use-cases/app.py                |  2 +-
#  use-cases/inference-on-model.py | 10 +++++++---
#  6 files changed, 12 insertions(+), 8 deletions(-)

# %%
# !pip install gdal osmnx==0.12 scikit-image statsmodels torchsummary utm numba jinja2==2.10 rasterio imagecodecs PyYAML>=5.3.1 opencv-python

# %% [markdown]
# Download pretrained Model

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1vC2u3TudZZWMNbSTS2um5EQtaQxGsg_a' -O /content/BEST-MODEL.pt
# Out:
# --2022-04-29 08:04:38--  https://docs.google.com/uc?export=download&id=1vC2u3TudZZWMNbSTS2um5EQtaQxGsg_a
# Resolving docs.google.com (docs.google.com)... 142.250.98.101, 142.250.98.139, 142.250.98.100, ...
# Connecting to docs.google.com (docs.google.com)|142.250.98.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-00-94-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/6dmf6q1chea6iuqp1ljrlvu0g7gf1g1v/1651219425000/12978598922595459377/*/1vC2u3TudZZWMNbSTS2um5EQtaQxGsg_a?e=download [following]
# ...
# --2022-04-29 08:04:40--  https://doc-00-94-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/6dmf6q1chea6iuqp1ljrlvu0g7gf1g1v/1651219425000/12978598922595459377/*/1vC2u3TudZZWMNbSTS2um5EQtaQxGsg_a?e=download
# Resolving doc-00-94-docs.googleusercontent.com (doc-00-94-docs.googleusercontent.com)... 74.125.141.132, 2607:f8b0:400c:c06::84
# ...

# %% [markdown]
# Use my Drive Example Orthomosaic

# %%
# %cd /content/yoltv5/yoltv5
# %mkdir /content/yoltv5/data
# !python /content/yoltv5/use-cases/inference-on-model.py -i /content/drive/MyDrive/DJI_0115.JPG -o /content/out -b /content/yoltv5/configs/yoltv5_test_flowers_base_JPG.yaml -m /content/BEST-MODEL.pt -t /content/yoltv5/yoltv5/test.py -y /content/yoltv5
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#    score: 0.675084
#   left, right, top, bottom: 4299.0 4309.0 3599.0 3610.0
#    classs: flower
#    score: 0.682375
#   left, right, top, bottom: 4319.0 4331.0 3537.0 3550.0
#    classs: flower
#    score: 0.691617
#   left, right, top, bottom: 4365.0 4376.0 3484.0 3496.0
#    classs: flower
#    score: 0.706704
#   left, right, top, bottom: 4147.0 4162.0 3529.0 3543.0
#    classs: flower
#    score: 0.723963
#   left, right, top, bottom: 4076.0 4088.0 3378.0 3389.0
#    classs: flower
#    score: 0.731411
#   left, right, top, bottom: 4088.0 4100.0 3566.0 3580.0
#    classs: flower
#    score: 0.733002
#   left, right, top, bottom: 4311.0 4323.0 3624.0 3635.0
#    classs: flower
#    score: 0.741004
#   left, right, top, bottom: 4337.0 4348.0 3619.0 3630.0
#    classs: flower
#    score: 0.745908
#   left, right, top, bottom: 4337.0 4347.0 3278.0 3290.0
#    classs: flower
#    score: 0.747533
# ...

# %%
# !pip install 
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

img = "/content/out/1651221390/yolov5-detection/results/1651221390/pred_plots_0p2/DJI_0115.jpg"
img = cv2.imread(img)
plt.imshow(img)
